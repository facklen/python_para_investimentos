# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipe-Pinto/python_para_investimentos/blob/master/Biblioteca_Fundamentus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Explorando a biblioteca Fundamentus**

# %%
# !pip install fundamentus

# %%
import fundamentus
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **Screening**

# %%
df = fundamentus.get_resultado()

# %%
df.head()
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AALR3        20.15  -17.59  2.22  2.183  0.0000  0.906 -29.06  79.32  -2.34
# ABCB3         0.00    0.00  0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# ABCB4        19.83    5.87  0.88  0.000  0.0645  0.000   0.00   0.00   0.00
# ABEV3        16.33   19.64  2.85  3.255  0.0369  1.810  39.10  16.72 -28.72
# ABYA3         4.91 -214.80  1.76  2.055  0.0000  0.527   1.98  19.96  -2.75
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# AALR3      101.36     20.81   0.0275 -0.1180  0.0132 -0.1263  0.86
# ABCB3        0.00      0.00   0.0000  0.0000  0.0000  0.1505  0.00
# ABCB4        0.00      0.00   0.0000  0.0000  0.0000  0.1505  0.00
# ABEV3       15.67     11.63   0.1947  0.1715  0.1498  0.1452  1.19
# ABYA3       33.67     33.67   0.1029 -0.0096  0.0278 -0.0082  2.09
#
# Multiples        liq2m       patrliq  divbpatr     c5y
# papel
# AALR3        6560730.0  1.072550e+09      0.85  0.0116
# ABCB3              0.0  5.070730e+09      0.00  0.3047
# ABCB4       18694500.0  5.070730e+09      0.00  0.3047
# ABEV3      460764000.0  9.017800e+10      0.03  0.1298
# ABYA3              0.0  2.920600e+08      1.31  0.1641

# %%
print(df.columns)
# Out:
# Index(['cotacao', 'pl', 'pvp', 'psr', 'dy', 'pa', 'pcg', 'pebit', 'pacl',
#        'evebit', 'evebitda', 'mrgebit', 'mrgliq', 'roic', 'roe', 'liqc',
#        'liq2m', 'patrliq', 'divbpatr', 'c5y'],
#       dtype='object', name='Multiples')

# %%
df.loc[['ABEV3', 'GOLL4','CRFB3'],['pl','pa','roic','roe']]
# Out:
# Multiples     pl     pa    roic     roe
# papel
# ABEV3      14.59  1.562  0.1576  0.1678
# GOLL4     -18.26  0.158  0.1122  0.0070
# CRFB3      48.58  0.217  0.0666  0.0197

# %%
setor = ['ABEV3', 'PETR4']

# %%
df.query('index in @setor')
# Out:
# Multiples  cotacao     pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# ABEV3        16.33  19.64  2.85  3.255  0.0369  1.810  39.10  16.72 -28.72
# PETR4        25.91   1.92  0.91  0.548  0.6460  0.357  14.37   1.19  -0.82
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# ABEV3       15.67     11.63   0.1947  0.1715  0.1498  0.1452  1.19
# PETR4        2.09      1.65   0.4623  0.2873  0.3230  0.4738  1.17
#
# Multiples         liq2m       patrliq  divbpatr     c5y
# papel
# ABEV3      4.607640e+08  9.017800e+10      0.03  0.1298
# PETR4      3.304490e+09  3.724980e+11      0.79  0.1536

# %% [markdown]
# Vamos criar um filtro:
#
# Queremos os papéis com P/L acima de 15 e DY acima de 5%

# %%
filtro = df[(df.pl > 15) & (df.dy > 0.05)]

# %%
filtro.shape
# Out:
# (15, 20)

# %%
filtro
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa    pcg  pebit  pacl  \
# papel
# AMER3         9.67  205.31  0.60  0.315  0.0638  0.187   0.71   7.29 -0.89
# CEPE5        40.12   36.07  2.11  0.375  0.1066  0.223   1.85   2.93 -0.37
# CEPE6        43.00   38.65  2.26  0.402  0.1094  0.239   1.98   3.14 -0.40
# CPLE11       39.20   24.43  1.02  0.937  0.0783  0.430   5.73   5.77 -1.20
# CPLE3         7.26   22.62  0.95  0.868  0.0783  0.399   5.30   5.34 -1.11
# CPLE6         7.99   24.89  1.04  0.955  0.0783  0.439   5.84   5.88 -1.22
# DESK3         9.96   18.75  0.94  1.366  4.4534  0.359  10.61   5.48 -0.83
# EEEL3       421.01   23.61  3.12  3.040  0.2999  0.948   5.56   5.46 -2.18
# EEEL4       410.00   23.00  3.04  2.961  0.3387  0.923   5.41   5.31 -2.12
# EGIE3        40.02   17.65  4.06  2.821  0.0704  0.823  16.90   5.70 -1.47
# GUAR3         7.70   15.11  0.75  0.460  0.0715  0.278   1.41  12.92 -6.40
# LCAM3        24.15   17.42  2.47  1.726  0.0564  0.575   5.09   5.57 -1.38
# MERC4         7.48   19.23  0.54  0.000  0.0610  0.000   0.00   0.00  0.00
# PATI4        51.99   16.62  1.37  0.500  0.0560  0.603   1.12  14.53  2.11
# STBP3         7.63   15.68  3.08  3.456  0.1185  1.328  12.71  12.19 -3.70
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# AMER3       17.39      6.63   0.0431  0.0015  0.0361  0.0029  2.24
# CEPE5        9.21      6.78   0.1278  0.0104  0.0894  0.0585  1.68
# CEPE6        9.42      6.94   0.1278  0.0104  0.0894  0.0585  1.68
# CPLE11       8.19      6.10   0.1624  0.0403  0.0856  0.0419  1.54
# CPLE3        7.76      5.78   0.1624  0.0403  0.0856  0.0419  1.54
# CPLE6        8.30      6.18   0.1624  0.0403  0.0856  0.0419  1.54
# DESK3        9.11      5.56   0.2494  0.0853  0.0770  0.0503  1.23
# EEEL3        6.42      6.42   0.5572  0.1190  0.1894  0.1323  2.91
# EEEL4        6.28      6.28   0.5572  0.1190  0.1894  0.1323  2.91
# EGIE3        8.31      6.97   0.4946  0.1600  0.1619  0.2300  1.26
# GUAR3       20.57      6.92   0.0356  0.0304  0.0251  0.0493  1.51
# LCAM3        9.94      7.57   0.3100  0.0991  0.1354  0.1421  1.48
# MERC4        0.00      0.00   0.0000  0.0000  0.0000  0.0279  0.00
# PATI4       14.79     13.15   0.0344  0.0301  0.0801  0.0823  2.74
# STBP3       11.40      8.08   0.2835  0.2204  0.1323  0.1964  1.99
#
# Multiples         liq2m       patrliq  divbpatr     c5y
# papel
# AMER3      4.444600e+08  1.470560e+10      1.41  0.4703
# CEPE5      7.640500e+02  1.420000e+09      5.40  0.1456
# CEPE6      2.944300e+02  1.420000e+09      5.40  0.1456
# CPLE11     2.159320e+07  2.096970e+10      0.64  0.1289
# CPLE3      1.033940e+07  2.096970e+10      0.64  0.1289
# CPLE6      1.335220e+08  2.096970e+10      0.64  0.1289
# DESK3      2.114520e+06  9.209070e+08      0.95  0.0000
# EEEL3      0.000000e+00  1.301400e+09      0.79  0.0595
# EEEL4      0.000000e+00  1.301400e+09      0.79  0.0595
# EGIE3      7.613170e+07  8.044930e+09      2.32  0.1027
# GUAR3      1.288270e+07  5.158500e+09      0.68  0.0265
# LCAM3      0.000000e+00  4.965670e+09      2.38  0.3855
# MERC4      2.883570e+03  2.513360e+08      0.00 -0.2646
# PATI4      1.237900e+02  9.101250e+08      0.75  0.3067
# STBP3      3.814950e+07  2.139970e+09      0.15  0.2003

# %%
plt.figure(figsize = (14, 16))
df.sort_values('mrgebit', inplace = True)
plt.bar(df.index, df.mrgebit)
# Out:
# <BarContainer object of 969 artists>

# %%
plt.figure(figsize = (10, 8))
filtro.sort_values('mrgebit', inplace = True)
plt.bar(filtro.index, filtro.mrgebit)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# <BarContainer object of 15 artists>

# %%
filtro2 = df[(df.pl > 0) & (df.dy > 0.05) & (df.mrgebit > 0.3)]

# %%
filtro2.shape
# Out:
# (35, 20)

# %%
filtro2.sort_values('dy', ascending = False, inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
plt.figure(figsize = (18, 8))
plt.bar(filtro2.index, filtro2.dy)
plt.xticks(rotation = 45)
plt.title("Ações com P/L maior que 0, margem Ebit maior que 30% e DY acima de 5%, ordenadas por DY")
# Out:
# Text(0.5, 1.0, 'Ações com P/L maior que 0, margem Ebit maior que 30% e DY acima de 5%, ordenadas por DY')
