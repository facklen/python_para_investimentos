# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipe-Pinto/python_para_investimentos/blob/master/Biblioteca_Fundamentus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Explorando a biblioteca Fundamentus**

# %%
# !pip install fundamentus

# %%
import fundamentus
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **Screening**

# %%
df = fundamentus.get_resultado()

# %%
df = fundamentus.get_resultado()

# %%
df.head()
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa      pcg   pebit  \
# papel
# AALR3         8.50   -3.51  1.16  0.888  0.0000  0.399    -3.12 -593.55
# ABCB3         0.00    0.00  0.00  0.000  0.0000  0.000     0.00    0.00
# ABCB4        19.53    5.47  0.81  0.000  0.0803  0.000     0.00    0.00
# ABEV3        13.04   14.39  2.41  2.484  0.0584  1.541  1015.29   12.61
# ABYA3         4.91 -214.80  1.76  2.055  0.0000  0.527     1.98   19.96
#
# Multiples   pacl   evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# AALR3      -0.81 -1122.25     16.55  -0.0015 -0.2460 -0.0007 -0.3311  0.55
# ABCB3       0.00     0.00      0.00   0.0000  0.0000  0.0000  0.1489  0.00
# ABCB4       0.00     0.00      0.00   0.0000  0.0000  0.0000  0.1489  0.00
# ABEV3     -16.30    12.09      8.85   0.1970  0.1779  0.1576  0.1678  1.01
# ABYA3      -2.75    33.67     33.67   0.1029 -0.0096  0.0278 -0.0082  2.09
#
# Multiples        liq2m       patrliq  divbpatr     c5y
# papel
# ...

# %%
print(df.columns)
# Out:
# Index(['cotacao', 'pl', 'pvp', 'psr', 'dy', 'pa', 'pcg', 'pebit', 'pacl',
#        'evebit', 'evebitda', 'mrgebit', 'mrgliq', 'roic', 'roe', 'liqc',
#        'liq2m', 'patrliq', 'divbpatr', 'c5y'],
#       dtype='object', name='Multiples')

# %%
df.loc[['ABEV3', 'GOLL4','CRFB3'],['pl','pa','roic','roe']]
# Out:
# Multiples     pl     pa    roic     roe
# papel
# ABEV3      14.39  1.541  0.1576  0.1678
# GOLL4     -18.03  0.156  0.1122  0.0070
# CRFB3      47.44  0.212  0.0666  0.0197

# %%
setor_A = ['ABEV3', 'GOLL4','CRFB3','NTCO3','VIIA3','WEGE3','PETR4','SBSP3','BEEF3','BRFS3','JBSS3','MFRG3']

# %%
Resultado_setor_A = df.query('index in @setor_A')
Resultado_setor_A
# Out:
# Multiples  cotacao     pl    pvp    psr      dy     pa      pcg   pebit  \
# papel
# ABEV3        13.04  14.39   2.41  2.484  0.0584  1.541  1015.29   12.61
# BEEF3         8.14  14.08  12.06  0.171  0.0677  0.249     1.26    2.29
# BRFS3         9.96  -4.89   1.83  0.309  0.0000  0.309     7.40  128.76
# CRFB3         8.71  47.44   0.94  0.166  0.0253  0.212   -10.75    4.11
# GOLL4         6.12 -18.03  -0.13  0.144  0.0000  0.156    -0.24    1.69
# JBSS3        17.84   8.52   0.93  0.108  0.1121  0.200     1.83   -0.79
# NTCO3        15.59  -7.61   1.05  0.625  0.0000  0.426     4.99   15.20
# PETR4        33.46   2.79   1.18  0.751  0.2765  0.441   -29.53    1.67
# SBSP3        60.01  12.76   1.43  1.725  0.0213  0.714  -218.45    8.27
# WEGE3        36.08  30.13   9.84  4.768  0.0166  5.204    15.92   22.17
#
# Multiples   pacl  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# ABEV3     -16.30   12.09      8.85   0.1970  0.1779  0.1576  0.1678  1.01
# ...

# %%
Ativos_Examinados = ['ABEV3', 'GOLL4','CRFB3','NTCO3','WEGE3','PETR4']

# %% [markdown]
# Vamos fazer alguns cálculos:
#
# Queremos os valores intrínsecos de determinados papéis.

# %%
Resultado_setor_A['VPA'] =Resultado_setor_A['cotacao']/Resultado_setor_A['pvp']
Resultado_setor_A.loc[['ABEV3', 'GOLL4','CRFB3','NTCO3','WEGE3','PETR4'],['VPA']]
# Out:
# <ipython-input-50-e80ac3438dff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Resultado_setor_A['VPA'] =Resultado_setor_A['cotacao']/Resultado_setor_A['pvp']
# Multiples        VPA
# papel
# ABEV3       5.410788
# GOLL4     -47.076923
# CRFB3       9.265957
# NTCO3      14.847619
# WEGE3       3.666667
# PETR4      28.355932

# %%
Resultado_setor_A['LPA'] =Resultado_setor_A['cotacao']/Resultado_setor_A['pl']
Resultado_setor_A.loc[['ABEV3', 'GOLL4','CRFB3','NTCO3','WEGE3','PETR4'],['LPA']]
# Out:
# <ipython-input-51-c3a01633dc6c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Resultado_setor_A['LPA'] =Resultado_setor_A['cotacao']/Resultado_setor_A['pl']
# Multiples        LPA
# papel
# ABEV3       0.906185
# GOLL4      -0.339434
# CRFB3       0.183600
# NTCO3      -2.048620
# WEGE3       1.197478
# PETR4      11.992832

# %%
import math

# %%
Resultado_setor_A['VI_Ativo1'] =Resultado_setor_A['LPA']*Resultado_setor_A['VPA']*22.5
Resultado_setor_A.loc[['ABEV3', 'GOLL4','CRFB3','NTCO3','WEGE3','PETR4'],['VI_Ativo1']]
# Out:
# <ipython-input-52-70083fab2df7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Resultado_setor_A['VI_Ativo1'] =Resultado_setor_A['LPA']*Resultado_setor_A['VPA']*22.5
# Multiples    VI_Ativo1
# papel
# ABEV3       110.321425
# GOLL4       359.539229
# CRFB3        38.277741
# NTCO3      -684.385489
# WEGE3        98.791902
# PETR4      7651.528157

# %%
Resultado_setor_A['VI_Ativo'] = Resultado_setor_A['VI_Ativo1']**(1/2)
Resultado_setor_A.loc[['ABEV3', 'GOLL4','CRFB3','NTCO3','WEGE3','PETR4'],['VI_Ativo']]
# Out:
# <ipython-input-53-ed4acfefdf69>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Resultado_setor_A['VI_Ativo'] = Resultado_setor_A['VI_Ativo1']**(1/2)
# Multiples   VI_Ativo
# papel
# ABEV3      10.503401
# GOLL4      18.961520
# CRFB3       6.186901
# NTCO3            NaN
# WEGE3       9.939412
# PETR4      87.473014

# %% [markdown]
# Vamos criar um filtro:
#
# Queremos os papéis com P/L acima de 15 e DY acima de 5%

# %%
filtro = df[(df.pl > 15) & (df.dy > 0.05)]

# %%
filtro.shape
# Out:
# (16, 20)

# %%
filtro
# Out:
# Multiples  cotacao     pl     pvp    psr       dy     pa    pcg   pebit  \
# papel
# AFLT3         8.15  19.77    2.06  7.107   0.0729  1.677  14.12   19.06
# ATOM3         2.30  24.79    2.82  2.041   0.1393  1.921   2.02 -176.05
# BSLI3        15.47  20.84    2.33  0.000   9.0521  0.000   0.00    0.00
# BSLI4        11.77  15.86    1.78  0.000  13.0874  0.000   0.00    0.00
# CGAS3       120.00  35.56  161.27  0.925   0.0974  1.154  81.02    5.43
# CGAS5       129.34  38.33  173.82  0.997   0.0994  1.244  87.33    5.86
# CRIV4         6.03  23.75    0.59  0.000   0.0796  0.000   0.00    0.00
# ENBR3        24.08  36.67    1.30  0.800   0.0590  0.384  -7.65    3.22
# PARD3        20.25  36.76    5.30  2.565   0.0584  2.095 -54.06   17.52
# PATI4        32.00  31.30    0.91  0.381   0.0659  0.437   0.89   19.37
# PGMN3         2.88  15.44    0.59  0.126   0.0618  0.158   0.99    4.19
# RAIZ4         3.74  15.32    1.71  0.170   0.0624  0.346  28.15    5.19
# ...

# %%
plt.figure(figsize = (10, 5))
df.sort_values('mrgebit', inplace = True)
plt.bar(df.index, df.mrgebit)
# Out:
# <BarContainer object of 967 artists>

# %%
plt.figure(figsize = (10, 8))
filtro.sort_values('mrgebit', inplace = True)
plt.bar(filtro.index, filtro.mrgebit)
# Out:
# <ipython-input-22-ed7f79164dc8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro.sort_values('mrgebit', inplace = True)
# <BarContainer object of 16 artists>

# %%
filtro2 = df[(df.pl > 0) & (df.dy > 0.05) & (df.mrgebit > 0.3)]

# %%
filtro2.shape
# Out:
# (26, 20)

# %%
filtro2.sort_values('dy', ascending = False, inplace = True)
# Out:
# <ipython-input-25-aede69897eac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro2.sort_values('dy', ascending = False, inplace = True)

# %%
plt.figure(figsize = (16, 4))
plt.bar(filtro2.index, filtro2.dy)
plt.xticks(rotation = 45)
plt.title("Ações com P/L maior que 0, margem Ebit maior que 30% e DY acima de 5%, ordenadas por DY")
# Out:
# Text(0.5, 1.0, 'Ações com P/L maior que 0, margem Ebit maior que 30% e DY acima de 5%, ordenadas por DY')
