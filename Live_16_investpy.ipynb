# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipe-Pinto/python_para_investimentos/blob/master/Live_16_investpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalando investpy

# %%
! pip install investpy
# Out:
# Collecting investpy
#   Downloading investpy-1.0.8.tar.gz (4.4 MB)
#      |████████████████████████████████| 4.4 MB 4.9 MB/s
# Collecting Unidecode>=1.1.1
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 41.2 MB/s
# Requirement already satisfied: setuptools>=41.2.0 in /usr/local/lib/python3.7/dist-packages (from investpy) (57.4.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from investpy) (1.21.6)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.7/dist-packages (from investpy) (1.3.5)
# Collecting lxml>=4.4.1
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 33.8 MB/s
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from investpy) (2.23.0)
# Requirement already satisfied: pytz>=2019.3 in /usr/local/lib/python3.7/dist-packages (from investpy) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.1->investpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->investpy) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->investpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->investpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->investpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->investpy) (2021.10.8)
# Building wheels for collected packages: investpy
#   Building wheel for investpy (setup.py) ... done
#   Created wheel for investpy: filename=investpy-1.0.8-py3-none-any.whl size=4481592 sha256=c9cba31e2d5d060eb5a72dd5da05dba14f5364b35b1754674df6d67e84dfe19c
#   Stored in directory: /root/.cache/pip/wheels/96/a8/a5/0d33c72eaf00b41df7b9dc1e15d2b7c7154b3f1379ed350211
# Successfully built investpy
# Installing collected packages: Unidecode, lxml, investpy
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed Unidecode-1.3.4 investpy-1.0.8 lxml-4.8.0

# %% [markdown]
# # Abrindo bibliotecas

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import investpy

# %% [markdown]
# # 1. Ações

# %%
search_results = investpy.search_quotes(text = 'PETR', products= ['stocks'], countries= ['brazil'], n_results = 50)

# %%
for search_result in search_results[1:2]:
  print(search_result)
# Out:
# {"id_": 18750, "name": "Petroleo Brasileiro SA PN", "symbol": "PETR4", "country": "brazil", "tag": "/equities/petrobras-pn", "pair_type": "stocks", "exchange": "BM&FBovespa"}

# %%
petr = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
# OHLC: Open, High, Low, Close
petr.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2014-01-02  15.49  15.54  15.04  15.13  17111300
# 2014-01-03  15.12  15.16  14.83  14.83  17598400
# 2014-01-06  14.86  15.03  14.60  15.01  20474600
# 2014-01-07  15.04  15.20  14.60  14.60  18785300
# 2014-01-08  14.70  14.81  14.59  14.62  15558400

# %%
petr['Close'].plot()

# %%
search_results = investpy.search_quotes(text = 'magazine', products= ['stocks'], countries= ['brazil'], n_results = 50)

for search_result in search_results:
  print(search_result)
# Out:
# {"id_": 18729, "name": "Magazine Luiza SA", "symbol": "MGLU3", "country": "brazil", "tag": "/equities/magaz-luiza-on-nm", "pair_type": "stocks", "exchange": "BM&FBovespa"}

# %%
mglu = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
mglu['Close'].plot()

# %% [markdown]
# # 2. Índices

# %%
search_results = investpy.search_quotes(text = 'bvsp', products= ['indices'], countries= ['brazil'], n_results = 50)

for search_result in search_results[:1]:
  print(search_result)
# Out:
# {"id_": 17920, "name": "Bovespa", "symbol": "BVSP", "country": "brazil", "tag": "/indices/bovespa", "pair_type": "indices", "exchange": "BM&FBovespa"}

# %%
ibov = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
ibov['Close'].plot()

# %% [markdown]
# # 3. ETFs

# %%
bova11 = investpy.get_etf_historical_data(etf = 'Ishares Ibovespa', country = 'brazil', from_date = '01/01/2014', to_date= '01/06/2021')

# %%
bova11['Close'].plot()

# %%
gld = investpy.get_etf_historical_data(etf = 'SPDR Gold Shares', country = 'united states', from_date = '01/01/2014', to_date= '01/06/2021')
gld['Close'].plot()

# %%
search_results = investpy.search_quotes(text = 'ewz', products= ['etfs'], countries= ['united states'], n_results = 50)

for search_result in search_results[:1]:
  print(search_result)
# Out:
# {"id_": 509, "name": "iShares MSCI Brazil ETF", "symbol": "EWZ", "country": "united states", "tag": "/etfs/ishares-brazil-index", "pair_type": "etfs", "exchange": "NYSE"}

# %%
ewz = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
ewz['Close'].plot()

# %% [markdown]
# # 4. Commodities

# %%
search_results = investpy.search_quotes(text = 'soy',
                                        products= ['commodities'],
                                        countries= ['brazil'],
                                        n_results = 50)

for search_result in search_results:
  print(search_result)
# Out:
# {"id_": 964523, "name": "US Soybeans Futures", "symbol": "SJCc1", "country": null, "tag": "/commodities/us-soybeans?cid=964523", "pair_type": "commodities", "exchange": "BM&FBovespa"}

# %%
soja_br = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
soja_br['Close'].plot()

# %%
search_results = investpy.search_quotes(text = 'corn', products= ['commodities'], countries= ['brazil'], n_results = 50)

for search_result in search_results:
  print(search_result)
# Out:
# {"id_": 1181089, "name": "US Corn Futures", "symbol": "CCMc3", "country": null, "tag": "/commodities/us-corn?cid=1181089", "pair_type": "commodities", "exchange": "BM&FBovespa"}
# {"id_": 1181088, "name": "US Corn Futures", "symbol": "CCMc2", "country": null, "tag": "/commodities/us-corn?cid=1181088", "pair_type": "commodities", "exchange": "BM&FBovespa"}
# {"id_": 964522, "name": "US Corn Futures", "symbol": "CCMc1", "country": null, "tag": "/commodities/us-corn?cid=964522", "pair_type": "commodities", "exchange": "BM&FBovespa"}

# %%
milho_br = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
milho_br['Close'].plot(figsize = (7,7))

# %%
search_results = investpy.search_quotes(text = 'cattle', products= ['commodities'], countries= ['brazil'], n_results = 50)

for search_result in search_results:
  print(search_result)
# Out:
# {"id_": 964528, "name": "Live Cattle Futures", "symbol": "BGIc1", "country": null, "tag": "/commodities/live-cattle?cid=964528", "pair_type": "commodities", "exchange": "BM&FBovespa"}
# {"id_": 1181094, "name": "Live Cattle Futures", "symbol": "BGIc2", "country": null, "tag": "/commodities/live-cattle?cid=1181094", "pair_type": "commodities", "exchange": "BM&FBovespa"}
# {"id_": 1181095, "name": "Live Cattle Futures", "symbol": "BGIc3", "country": null, "tag": "/commodities/live-cattle?cid=1181095", "pair_type": "commodities", "exchange": "BM&FBovespa"}

# %%
boi_gordo = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
boi_gordo['Close'].plot(figsize = (7,7))

# %%
search_results = investpy.search_quotes(text = 'lumber', products= ['commodities'], countries= ['united states'], n_results = 50)

for search_result in search_results:
  print(search_result)
# Out:
# {"id_": 959198, "name": "Lumber Futures", "symbol": "LBc1", "country": null, "tag": "/commodities/lumber", "pair_type": "commodities", "exchange": "CME"}
# {"id_": 1178209, "name": "Lumber Futures", "symbol": "LBc2", "country": null, "tag": "/commodities/lumber?cid=1178209", "pair_type": "commodities", "exchange": "CME"}
# {"id_": 1178210, "name": "Lumber Futures", "symbol": "LBc3", "country": null, "tag": "/commodities/lumber?cid=1178210", "pair_type": "commodities", "exchange": "CME"}

# %%
lumber = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
lumber['Close'].plot(figsize = (7,7))

# %%
search_results = investpy.search_quotes(text = 'uranium', products= ['commodities'], countries= ['united states'], n_results = 50)

for search_result in search_results:
  print(search_result)
# Out:
# {"id_": 961731, "name": "Uranium Futures", "symbol": "UXXc2", "country": null, "tag": "/commodities/uranium-futures", "pair_type": "commodities", "exchange": "CME"}
# {"id_": 1181085, "name": "Uranium Futures", "symbol": "UXXc3", "country": null, "tag": "/commodities/uranium-futures?cid=1181085", "pair_type": "commodities", "exchange": "CME"}

# %%
uranium = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
uranium['Close'].plot(figsize = (7,7))

# %% [markdown]
# # 5. Criptomoedas

# %%
dogecoin = investpy.get_crypto_historical_data(crypto = 'dogecoin', from_date= '01/01/2014', to_date='01/06/2021')

# %%
dogecoin.head()
# Out:
#                 Open      High       Low     Close   Volume Currency
# Date
# 2017-06-03  0.002803  0.003398  0.002655  0.003213  4369225      USD
# 2017-06-04  0.003213  0.003770  0.002544  0.003770  5963160      USD
# 2017-06-05  0.003770  0.003825  0.002923  0.003718  4823315      USD
# 2017-06-06  0.003718  0.003718  0.003152  0.003617  2114105      USD
# 2017-06-07  0.003617  0.003950  0.003132  0.003250  1371475      USD

# %%
dogecoin['Close'].plot()

# %% [markdown]
# # 6. Tesouro Direto

# %%
search_results = investpy.search_quotes(text = 'tesouro', products= ['bonds'], countries= ['brazil'], n_results = 50)

for search_result in search_results[6:7]:
  print(search_result)
# Out:
# {"id_": 1089897, "name": "Tesouro IPCA + NTNB 6 15-May-2045", "symbol": "NTB051545=", "country": "brazil", "tag": "/rates-bonds/ntnb-6-15-may-2045", "pair_type": "bonds", "exchange": "OTC Bonds"}

# %%
ipca_2045 = search_result.retrieve_historical_data(from_date = '01/01/2019', to_date = '01/07/2021')

# %%
ipca_2045.head()
# Out:
#                 Open      High       Low     Close  Change Pct
# Date
# 2019-01-02  3651.118  3651.118  3651.118  3651.118        0.18
# 2019-01-03  3687.068  3687.068  3687.068  3687.068        0.98
# 2019-01-04  3718.380  3718.380  3718.380  3718.380        0.85
# 2019-01-07  3719.077  3719.077  3719.077  3719.077        0.02
# 2019-01-08  3735.218  3735.218  3735.218  3735.218        0.43

# %%
ipca_2045.plot()
